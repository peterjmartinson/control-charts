# %%
# Import all the goods
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
plt.style.use('seaborn-whitegrid')

# Import the data files
xl_01 = pd.ExcelFile('FallOfTheHouseOfUsher_Frequencies.xlsx')
all_data = xl_01.parse("Data")
all_data
# Out:
#     Paragraph Number                                     Paragraph Text  \
# 0                  1  During the whole of a dull, dark, and soundles...
# 1                  2  Nevertheless, in this mansion of gloom I now p...
# 2                  3  Although, as boys, we had been even intimate a...
# 3                  4  I have said that the sole effect of my somewha...
# 4                  5  Noticing these things, I rode over a short cau...
# 5                  6  The room in which I found myself was very larg...
# 6                  7  Upon my entrance, Usher rose from a sofa on wh...
# 7                  8  In the manner of my friend I was at once struc...
# 8                  9  It was thus that he spoke of the object of my ...
# 9                 10  To an anomalous species of terror I found him ...
# 10                11  I learned, moreover, at intervals, and through...
# 11                12  He admitted, however, although with hesitation...
# ...

# %%
periods = all_data[['Paragraph Number', 'Word Count', 'Dashes', 'Dashes per word']]
periods
# Out:
#     Paragraph Number  Word Count  Dashes  Dashes per word
# 0                  1         389      19            0.049
# 1                  2         162      12            0.074
# 2                  3         269       5            0.019
# 3                  4         377      17            0.045
# 4                  5         199       6            0.030
# 5                  6         137       0            0.000
# 6                  7         324       4            0.012
# 7                  8         135      10            0.074
# 8                  9         170       2            0.012
# 9                 10         112       6            0.054
# 10                11         118       7            0.059
# 11                12         194      15            0.077
# 12                13         125       2            0.016
# 13                14         111       0            0.000
# 14                15         243       6            0.025
# ...

# %%
central_line = sum(periods['Dashes per word'])/periods['Dashes per word'].count()
central_line
# Out:
# 0.037680851063829776

# %%
upper_limit = central_line + np.sqrt( (central_line * (1 - central_line)) / periods['Dashes per word'])
upper_limit
# Out:
# 0     0.897925
# 1     0.737691
# 2     1.419156
# 3     0.935345
# 4     1.137090
# 5          inf
# 6     1.775999
# 7     0.737691
# 8     1.775999
# 9     0.857132
# 10    0.821641
# 11    0.723919
# 12    1.543109
# 13         inf
# 14    1.242023
# 15         inf
# 16         inf
# 17    0.522924
# 18    0.645966
# 19         inf
# 20         inf
# 21    1.321514
# 22    0.752326
# 23    1.027644
# 24    0.889279
# 25    2.730672
# 26    2.496034
# 27    1.853295
# 28    1.351726
# 29    1.119212
# 30    0.796345
# 31    0.710929
# 32    1.293294
# 33    0.672425
# 34         inf
# 35    1.384176
# 36    2.044918
# 37    1.592480
# 38    1.647051
# 39    0.857132
# 40    1.384176
# 41         inf
# 42    1.155885
# 43    0.486513
# 44    0.880889
# 45    0.752326
# 46         inf
# Name: Dashes per word, dtype: float64

# %%
lower_limit = central_line - np.sqrt( (central_line * (1 - central_line)) / periods['Dashes per word'])
lower_limit
# Out:
# 0    -0.822564
# 1    -0.662329
# 2    -1.343794
# 3    -0.859983
# 4    -1.061728
# 5         -inf
# 6    -1.700637
# 7    -0.662329
# 8    -1.700637
# 9    -0.781770
# 10   -0.746279
# 11   -0.648557
# 12   -1.467747
# 13        -inf
# 14   -1.166661
# 15        -inf
# 16        -inf
# 17   -0.447562
# 18   -0.570604
# 19        -inf
# 20        -inf
# 21   -1.246152
# 22   -0.676965
# 23   -0.952282
# 24   -0.813918
# 25   -2.655310
# 26   -2.420672
# 27   -1.777933
# 28   -1.276364
# 29   -1.043850
# 30   -0.720983
# 31   -0.635567
# 32   -1.217933
# 33   -0.597063
# 34        -inf
# 35   -1.308815
# 36   -1.969556
# 37   -1.517118
# 38   -1.571689
# 39   -0.781770
# 40   -1.308815
# 41        -inf
# 42   -1.080523
# 43   -0.411151
# 44   -0.805527
# 45   -0.676965
# 46        -inf
# Name: Dashes per word, dtype: float64

# %%
fig, ax = plt.subplots()

ax.step(lower_limit.index, lower_limit.values, where='mid')
ax.step(upper_limit.index, upper_limit.values, where='mid')
ax.axhline(central_line)
ax.plot(periods['Dashes per word'])
#ax.set_ylim(-0.5, 0.5)
